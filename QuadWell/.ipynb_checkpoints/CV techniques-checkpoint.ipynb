# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from os.path import join
import pickle
from sklearn.model_selection import KFold, cross_val_score, ShuffleSplit

# %%
model = pickle.load(open('model.pickl', 'rb'))
model
# Out:
# Pipeline(steps=[('cluster', NDGrid(max=1.2, min=-1.2, n_bins_per_feature=200)), ('msm', MaximumLikelihoodMSM(connectivity='largest', count_mode='sliding',
#            dt_traj='1 step', lag=25, maxerr=1e-08, maxiter=1000000,
#            mincount_connectivity='1/n', reversible=True, score_k=10,
#            score_method='VAMP2', sparse=False, statdist_constraint=None))])

# %%
paths = ['data/000.5pc/quad_well_{:02d}.npy'.format(x) for x in range(100)]
# paths
X = [np.load(x) for x in paths]

# %%
model.set_params(cluster__n_bins_per_feature=200)
model.set_params(msm__score_k=4)
# Out:
# Pipeline(steps=[('cluster', NDGrid(max=1.2, min=-1.2, n_bins_per_feature=200)), ('msm', MaximumLikelihoodMSM(connectivity='largest', count_mode='sliding',
#            dt_traj='1 step', lag=25, maxerr=1e-08, maxiter=1000000,
#            mincount_connectivity='1/n', reversible=True, score_k=4,
#            score_method='vampe', sparse=False, statdist_constraint=None))])

# %%
data = {'score_method':[], 'cv_method': [], 'n_splits': [], 'MCV': [], 'MCV_err': []}
score_methods = ['vamp1', 'vamp2', 'vampe']
cv_methods = {'KFold': KFold(), 'ShuffleSplit': ShuffleSplit(test_size=.5, random_state=42)}
n_splits = np.arange(5,100,10)

# %%
for score_method in score_methods:
    model.set_params(msm__score_method=score_method)
    model.set_params(msm__score_k=4)    
    for k, v in cv_methods.items():
        for n in n_splits:
            print(score_method, k, n, end=', ')
            
            v.n_splits=n
            scores = cross_val_score(model, X, cv=v)
            data['score_method'].append(score_method)
            data['cv_method'].append(k)
            data['n_splits'].append(n)
            data['MCV'].append(np.mean(scores))
            data['MCV_err'].append(np.std(scores))
# Out:
# vamp1 ShuffleSplit 5, vamp1 ShuffleSplit 15, vamp1 ShuffleSplit 25, vamp1 ShuffleSplit 35, vamp1 ShuffleSplit 45, vamp1 ShuffleSplit 55, vamp1 ShuffleSplit 65, vamp1 ShuffleSplit 75, vamp1 ShuffleSplit 85, vamp1 ShuffleSplit 95, vamp1 KFold 5, vamp1 KFold 15, vamp1 KFold 25, vamp1 KFold 35, vamp1 KFold 45, vamp1 KFold 55, vamp1 KFold 65, vamp1 KFold 75, vamp1 KFold 85, vamp1 KFold 95, vamp2 ShuffleSplit 5, vamp2 ShuffleSplit 15, vamp2 ShuffleSplit 25, vamp2 ShuffleSplit 35, vamp2 ShuffleSplit 45, vamp2 ShuffleSplit 55, vamp2 ShuffleSplit 65, vamp2 ShuffleSplit 75, vamp2 ShuffleSplit 85, vamp2 ShuffleSplit 95, vamp2 KFold 5, vamp2 KFold 15, vamp2 KFold 25, vamp2 KFold 35, vamp2 KFold 45, vamp2 KFold 55, vamp2 KFold 65, vamp2 KFold 75, vamp2 KFold 85, vamp2 KFold 95, vampe ShuffleSplit 5, vampe ShuffleSplit 15, vampe ShuffleSplit 25, vampe ShuffleSplit 35, vampe ShuffleSplit 45, vampe ShuffleSplit 55, vampe ShuffleSplit 65, vampe ShuffleSplit 75, vampe ShuffleSplit 85, vampe ShuffleSplit 95, vampe KFold 5, vampe KFold 15, vampe KFold 25, vampe KFold 35, vampe KFold 45, vampe KFold 55, vampe KFold 65, vampe KFold 75, vampe KFold 85, vampe KFold 95,

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#         MCV   MCV_err     cv_method  n_splits score_method
# 0  3.460369  0.021202  ShuffleSplit         5        vamp1
# 1  3.470511  0.019164  ShuffleSplit        15        vamp1
# 2  3.464953  0.023825  ShuffleSplit        25        vamp1
# 3  3.464098  0.023486  ShuffleSplit        35        vamp1
# 4  3.464853  0.024209  ShuffleSplit        45        vamp1

# %%
g = sns.FacetGrid(data=df, col='score_method', row='cv_method', sharey=False)
g.map(plt.plot, 'n_splits', 'MCV_err').add_legend()

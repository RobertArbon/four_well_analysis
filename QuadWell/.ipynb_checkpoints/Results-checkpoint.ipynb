# %%
import pandas as pd
import numpy as np
from osprey.config import Config
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from os.path import join

# %%
frac_min, frac_max = 0.005, 1
fractions = [x for x in np.logspace(np.log10(frac_min), np.log10(frac_max), 5)]
result_dirs = ['data/{:05.1f}pc'.format(x*100) for x in fractions]

# all_dfs = []
# for i, result_dir in enumerate(result_dirs): 
#     df = Config(join(result_dir, 'config.yaml')).trial_results()
#     df['data_fraction'] = fractions[i]
#     all_dfs.append(df)
    
# df = pd.concat(all_dfs)
i = 0
result_dir = result_dirs[i]
df = Config(join(result_dir, 'config.yaml')).trial_results()
df['data_fraction'] = fractions[i]
# Out:
# Loading config file:     data/000.5pc/config.yaml...
# Loading trials database: sqlite:///osprey-trials.db...

# %%
df.tail()
# Out:
#                        completed                               config_sha1  \
# 1495  2017-12-11 15:25:13.429782  8192ac0e3873aad11a4d7b6fda5f2e8f23142281
# 1496  2017-12-11 15:25:17.175548  8192ac0e3873aad11a4d7b6fda5f2e8f23142281
# 1497  2017-12-11 15:25:20.825878  8192ac0e3873aad11a4d7b6fda5f2e8f23142281
# 1498  2017-12-11 15:25:24.334400  8192ac0e3873aad11a4d7b6fda5f2e8f23142281
# 1499  2017-12-11 15:25:27.941545  8192ac0e3873aad11a4d7b6fda5f2e8f23142281
#
#                          elapsed                      host    id  \
# 1495  1970-01-01 00:00:03.391825  compute108.bc4.acrc.priv  1496
# 1496  1970-01-01 00:00:03.628282  compute108.bc4.acrc.priv  1497
# 1497  1970-01-01 00:00:03.519894  compute108.bc4.acrc.priv  1498
# 1498  1970-01-01 00:00:03.383889  compute108.bc4.acrc.priv  1499
# 1499  1970-01-01 00:00:03.487409  compute108.bc4.acrc.priv  1500
#
#       mean_test_score  mean_train_score                  n_test_samples  \
# 1495         3.011863          3.368291  [8440, 8440, 8440, 8440, 8440]
# 1496         1.135575          3.327680  [8440, 8440, 8440, 8440, 8440]
# 1497         3.453729          4.107877  [8440, 8440, 8440, 8440, 8440]
# 1498         3.013064          3.423903  [8440, 8440, 8440, 8440, 8440]
# 1499         1.031555          3.334510  [8440, 8440, 8440, 8440, 8440]
#
#                           n_train_samples  \
# 1495  [33760, 33760, 33760, 33760, 33760]
# 1496  [33760, 33760, 33760, 33760, 33760]
# 1497  [33760, 33760, 33760, 33760, 33760]
# 1498  [33760, 33760, 33760, 33760, 33760]
# 1499  [33760, 33760, 33760, 33760, 33760]
#
#                                              parameters project_name  \
# 1495  {'msm__count_mode': 'sliding', 'msm__score_k':...      default
# 1496  {'msm__count_mode': 'sliding', 'msm__score_k':...      default
# 1497  {'msm__count_mode': 'sliding', 'msm__score_k':...      default
# 1498  {'msm__count_mode': 'sliding', 'msm__score_k':...      default
# 1499  {'msm__count_mode': 'sliding', 'msm__score_k':...      default
#
#                          started     status  \
# 1495  2017-12-11 15:25:10.037957  SUCCEEDED
# 1496  2017-12-11 15:25:13.547266  SUCCEEDED
# 1497  2017-12-11 15:25:17.305984  SUCCEEDED
# 1498  2017-12-11 15:25:20.950511  SUCCEEDED
# 1499  2017-12-11 15:25:24.454136  SUCCEEDED
#
#                                             test_scores traceback  \
# 1495  [3.0417366673680317, 2.9262662029153654, 3.127...      None
# 1496  [0.2710527566791341, 1.3661725665152868, 1.352...      None
# 1497  [3.4367326441758688, 3.413015649943554, 3.5410...      None
# 1498  [3.0423274608928725, 2.928660912387116, 3.1279...      None
# 1499  [-0.21911619582794978, 1.3416778932827134, 1.3...      None
#
#                                            train_scores     user  \
# 1495  [4.056769418108105, 3.186589721846564, 3.17466...  ra15808
# 1496  [3.8544074334383107, 3.1865822252144684, 3.174...  ra15808
# 1497  [4.522825329580859, 3.990275996730844, 3.98291...  ra15808
# 1498  [4.0607999739653655, 3.24437764380185, 3.23274...  ra15808
# 1499  [3.6571847795716357, 3.244062197957818, 3.2322...  ra15808
#
#       data_fraction
# 1495          0.005
# 1496          0.005
# 1497          0.005
# 1498          0.005
# 1499          0.005

# %%
df = df.loc[:, ['parameters', 'test_scores', 'train_scores', 'data_fraction']]

# %%
static_params = df.loc[0, 'parameters']
static_params
# Out:
# {'cluster__max': 1.2,
#  'cluster__min': -1.2,
#  'cluster__n_bins_per_feature': 10,
#  'msm__connectivity': 'largest',
#  'msm__count_mode': 'sliding',
#  'msm__dt_traj': '1 step',
#  'msm__lag': 25,
#  'msm__maxerr': 1e-08,
#  'msm__maxiter': 1000000,
#  'msm__mincount_connectivity': '1/n',
#  'msm__reversible': True,
#  'msm__score_k': 2,
#  'msm__score_method': 'vamp1',
#  'msm__sparse': False,
#  'msm__statdist_constraint': None}

# %%
variables = ['msm__score_k', 'msm__score_method', 'cluster__n_bins_per_feature']
for variable in variables: 
    df[variable] = df['parameters'].apply(lambda x: x[variable])
del df['parameters']

# %%
for x in ['test', 'train']:
    df[x+'_scores_std'] = df[x+'_scores'].apply(lambda x: np.std(x))
    df[x+'_scores_mean'] = df[x+'_scores'].apply(lambda x: np.mean(x))
    del df[x+'_scores']

# %%
df.rename(columns={'msm__score_k': 'k', 'msm__score_method': 'method','cluster__n_bins_per_feature': 'clusters'}, 
         inplace=True)
df.head()
# Out:
#    data_fraction  k method  clusters  test_scores_std  test_scores_mean  \
# 0          0.005  2  vamp1        10         0.013982          1.973972
# 1          0.005  2  vamp2        10         0.027020          1.948818
# 2          0.005  2  vampe        10         0.029138          0.855020
# 3          0.005  3  vamp1        10         0.043417          2.759368
# 4          0.005  3  vamp2        10         0.072088          2.567230
#
#    train_scores_std  train_scores_mean
# 0          0.003402           1.975411
# 1          0.006649           1.951438
# 2          0.006649           1.951438
# 3          0.009944           2.774802
# 4          0.016954           2.590518

# %%
cols = sns.color_palette('colorblind')
g = sns.FacetGrid(data=df, row='method', col='k', sharey='row')
g.map(plt.plot, 'clusters', 'test_scores_mean', alpha=1, color=cols[0])
g.map(plt.plot, 'clusters', 'train_scores_mean', alpha=1, color=cols[1])

# %%
best_scores = df.groupby(['data_fraction',  'method', 'k'])['test_scores_mean'].max()
best_scores
# Out:
# data_fraction  method  k
# 0.005          vamp1   2    1.976193
#                        3    2.782325
#                        4    3.441287
#                        5    3.534588
#                        6    3.596360
#                vamp2   2    1.953108
#                        3    2.604235
#                        4    3.040340
#                        5    3.056203
#                        6    3.070228
#                vampe   2    0.857014
#                        3    1.155515
#                        4    1.358767
#                        5    1.362516
#                        6    1.363447
# Name: test_scores_mean, dtype: float64

# %%
best_idx = df.groupby(['data_fraction',  
                       'method', 'k'])['test_scores_mean'].transform(max) == df['test_scores_mean']

best_df = df.loc[best_idx, :].sort_values(by=['data_fraction',  'method', 'k'])

# %% [markdown]
# ## k=4 only

# %%
methods = df['method'].unique()

# %%
k = 4
df_sample = df.loc[df['k']==k, :]
best_df_sample = best_df.loc[df['k']==k, :]
cols = sns.color_palette('colorblind', 3)
print(cols)
# Out:
# [(0.0, 0.4470588235294118, 0.6980392156862745), (0.0, 0.6196078431372549, 0.45098039215686275), (0.8352941176470589, 0.3686274509803922, 0.0)]

# %%
best_df_sample
# Out:
#      data_fraction  k method  clusters  test_scores_std  test_scores_mean  \
# 126          0.005  4  vamp1        90         0.053023          3.441287
# 127          0.005  4  vamp2        90         0.082602          3.040340
# 128          0.005  4  vampe        90         0.022985          1.358767
#
#      train_scores_std  train_scores_mean
# 126          0.007342           3.483827
# 127          0.013022           3.100368
# 128          0.013023           3.100367

# %%
with sns.plotting_context('paper', font_scale=2):
    g = sns.FacetGrid(data=df_sample,  col='method', col_order = methods, sharey=False)
    g.map(plt.errorbar, 'clusters', 'test_scores_mean', 'test_scores_std', 
          alpha=0.8, color=cols[0], elinewidth=.5)
    # g.map(plt.errorbar, 'cluster__n_bins_per_feature', 'train_scores_mean', 'train_scores_std', 
    #       alpha=0.8, color=cols[0], elinewidth=.5)
    for i, ax in enumerate(g.axes[0]):
        x = best_df_sample.loc[best_df_sample['method']==methods[i], 'clusters']
        y = best_df_sample.loc[best_df_sample['method']==methods[i], 'test_scores_mean']
        ax.scatter(x, y, c=cols[-1], marker='x', s=50)
        label = 'Optimum discretization:\n{} clusters'.format(x.values[0])

        ax.annotate(label,
                xy=(x, y), xycoords='data',
                xytext=(.1, .1),  textcoords='axes fraction', 
                arrowprops=dict(arrowstyle="->",
                                connectionstyle="arc3"),
                )

    plt.savefig('k4.pdf')
# g.map(plt.errorbar, 'cluster__n_bins_per_feature', 'train_scores_mean','train_scores_std',  alpha=1, color=cols[1])

# %%
import pandas as pd
import numpy as np
from osprey.config import Config
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
all_dfs = []
for i in range(1,6):
    df = Config('run{}/config-k2.yaml'.format(i)).trial_results()
    df['run'] = i
    all_dfs.append(df)
total_df = pd.concat(all_dfs)
# Out:
# Loading config file:     run1/config-k2.yaml...
# Loading trials database: sqlite:///osprey-trials.db...
# Loading config file:     run2/config-k2.yaml...
# Loading trials database: sqlite:///osprey-trials.db...
# Loading config file:     run3/config-k2.yaml...
# Loading trials database: sqlite:///osprey-trials.db...
# Loading config file:     run4/config-k2.yaml...
# Loading trials database: sqlite:///osprey-trials.db...
# Loading config file:     run5/config-k2.yaml...
# Loading trials database: sqlite:///osprey-trials.db...

# %%
total_df.head()
# Out:
#                     completed                               config_sha1  \
# 0  2018-01-13 17:08:56.304206  f5073bf84a2ea9a51d7dc4570b17242bc0fecb63
# 1  2018-01-13 17:08:54.628764  5474c1fc7b1e29205c0f08bac137d2ca5bd6aeba
# 2  2018-01-13 17:08:55.159273  bdf0a1ddc0722652ffe0373011e9c826e64895aa
# 3  2018-01-13 17:08:55.294398  e73721a3483fc1f7772c85760adbde080bf696ef
# 4  2018-01-13 17:08:55.653295  5474c1fc7b1e29205c0f08bac137d2ca5bd6aeba
#
#                       elapsed                      host  id  mean_test_score  \
# 0  1970-01-01 00:00:03.006746  compute163.bc4.acrc.priv   1         3.087604
# 1  1970-01-01 00:00:01.149366  compute163.bc4.acrc.priv   2         3.070904
# 2  1970-01-01 00:00:00.980451  compute163.bc4.acrc.priv   3         1.933060
# 3  1970-01-01 00:00:01.000071  compute163.bc4.acrc.priv   4         2.612803
# 4  1970-01-01 00:00:01.004790  compute163.bc4.acrc.priv   5         3.077725
#
#    mean_train_score        n_test_samples       n_train_samples  \
# 0          3.098339  [50, 50, 50, 50, 50]  [50, 50, 50, 50, 50]
# 1          3.082066  [50, 50, 50, 50, 50]  [50, 50, 50, 50, 50]
# 2          1.942413  [50, 50, 50, 50, 50]  [50, 50, 50, 50, 50]
# 3          2.615377  [50, 50, 50, 50, 50]  [50, 50, 50, 50, 50]
# 4          3.076566  [50, 50, 50, 50, 50]  [50, 50, 50, 50, 50]
#
#                                           parameters project_name  \
# 0  {'msm__dt_traj': '1 step', 'msm__lag': 25, 'ms...           k5
# 1  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k4
# 2  {'msm__dt_traj': '1 step', 'msm__lag': 25, 'ms...           k2
# 3  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k3
# 4  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k4
#
#                       started     status  \
# 0  2018-01-13 17:08:53.297460  SUCCEEDED
# 1  2018-01-13 17:08:53.479398  SUCCEEDED
# 2  2018-01-13 17:08:54.178822  SUCCEEDED
# 3  2018-01-13 17:08:54.294327  SUCCEEDED
# 4  2018-01-13 17:08:54.648505  SUCCEEDED
#
#                                          test_scores traceback  \
# 0  [3.0867290945208, 3.0808565586817154, 3.089550...      None
# 1  [3.067095056978774, 3.0675485197144945, 3.0711...      None
# 2  [1.9303607145786001, 1.942842868108373, 1.9418...      None
# 3  [2.618083697646979, 2.6105326052190314, 2.6098...      None
# 4  [3.078569698363513, 3.0932897326275817, 3.0727...      None
#
#                                         train_scores     user  run
# 0  [3.1047279423548604, 3.0844412189758543, 3.100...  ra15808    1
# 1  [3.0831352339509692, 3.081269430199865, 3.0796...  ra15808    1
# 2  [1.941609154629563, 1.9416226554503795, 1.9426...  ra15808    1
# 3  [2.6118889510793286, 2.6185907907793076, 2.613...  ra15808    1
# 4  [3.077536190393716, 3.0654088929117433, 3.0753...  ra15808    1

# %%
df = total_df.loc[:, ['parameters', 'project_name', 'test_scores', 'train_scores', 'run', 'started']]

# %%
df.head()
# Out:
#                                           parameters project_name  \
# 0  {'msm__dt_traj': '1 step', 'msm__lag': 25, 'ms...           k5
# 1  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k4
# 2  {'msm__dt_traj': '1 step', 'msm__lag': 25, 'ms...           k2
# 3  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k3
# 4  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k4
#
#                                          test_scores  \
# 0  [3.0867290945208, 3.0808565586817154, 3.089550...
# 1  [3.067095056978774, 3.0675485197144945, 3.0711...
# 2  [1.9303607145786001, 1.942842868108373, 1.9418...
# 3  [2.618083697646979, 2.6105326052190314, 2.6098...
# 4  [3.078569698363513, 3.0932897326275817, 3.0727...
#
#                                         train_scores  run  \
# 0  [3.1047279423548604, 3.0844412189758543, 3.100...    1
# 1  [3.0831352339509692, 3.081269430199865, 3.0796...    1
# 2  [1.941609154629563, 1.9416226554503795, 1.9426...    1
# 3  [2.6118889510793286, 2.6185907907793076, 2.613...    1
# 4  [3.077536190393716, 3.0654088929117433, 3.0753...    1
#
#                       started
# 0  2018-01-13 17:08:53.297460
# 1  2018-01-13 17:08:53.479398
# 2  2018-01-13 17:08:54.178822
# 3  2018-01-13 17:08:54.294327
# 4  2018-01-13 17:08:54.648505

# %%
df['step'] = 0
df.sort_values(ascending=True, by='started', inplace=True)

# %%
df['step'] = df.groupby([ 'run','project_name']).cumcount(ascending=True)

# %%
df.loc[(df['project_name']=='k2') & (df['run']==2), :].head(10)
# Out:
#                                            parameters project_name  \
# 0   {'msm__dt_traj': '1 step', 'msm__connectivity'...           k2
# 9   {'msm__dt_traj': '1 step', 'msm__connectivity'...           k2
# 14  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k2
# 17  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k2
# 19  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k2
# 23  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k2
# 27  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k2
# 29  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k2
# 35  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k2
# 40  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k2
#
#                                           test_scores  \
# 0   [1.9420516287574867, 1.9417225266320988, 1.935...
# 9   [1.9428448075256397, 1.9396287665938312, 1.942...
# 14  [1.9364592431584817, 1.9376227982373766, 1.928...
# 17  [1.9379216729289512, 1.8837302136460634, 1.935...
# 19  [1.9319218006778742, 1.9447564018592132, 1.917...
# 23  [1.9354375963920787, 1.9417631018383423, 1.941...
# 27  [1.9390916645138674, 1.9271071349193245, 1.911...
# 29  [1.938737716335467, 1.9414677519196866, 1.9426...
# 35  [1.9301519400474254, 1.9379032518038752, 1.920...
# 40  [1.9374143950843086, 1.9422504425947094, 1.939...
#
#                                          train_scores  run  \
# 0   [1.9424079743312872, 1.9406509025036605, 1.945...    2
# 9   [1.941844030431417, 1.9434816274424325, 1.9413...    2
# 14  [1.9426933464266782, 1.9418297158895172, 1.943...    2
# 17  [1.9432406107483866, 1.94033412998373, 1.94229...    2
# 19  [1.9420581333617335, 1.9397837830476554, 1.942...    2
# 23  [1.9417885552376961, 1.942870843433367, 1.9424...    2
# 27  [1.9413573522136174, 1.942889612092315, 1.9446...    2
# 29  [1.9441295305342328, 1.9427893100931255, 1.940...    2
# 35  [1.9403856645886646, 1.93940309482051, 1.93905...    2
# 40  [1.9437543833850228, 1.9417306379398105, 1.944...    2
#
#                        started  step
# 0   2018-01-13 17:16:27.883516     0
# 9   2018-01-13 17:16:32.269883     1
# 14  2018-01-13 17:16:36.899431     2
# 17  2018-01-13 17:16:37.837786     3
# 19  2018-01-13 17:16:38.807772     4
# 23  2018-01-13 17:16:44.363566     5
# 27  2018-01-13 17:16:51.574609     6
# 29  2018-01-13 17:16:59.194485     7
# 35  2018-01-13 17:17:06.668451     8
# 40  2018-01-13 17:17:14.329439     9

# %%
df['k'] = df['parameters'].apply(lambda x: int(x['msm__score_k']))

# %%
df['m'] = df['parameters'].apply(lambda x: int(x['cluster__n_bins_per_feature']))

# %%
df['MCV_train'] = df['train_scores'].apply(lambda x: np.mean(x))
df['MCV_test'] = df['test_scores'].apply(lambda x: np.mean(x))

# %%
df.head()
# Out:
#                                           parameters project_name  \
# 0  {'msm__dt_traj': '1 step', 'msm__lag': 25, 'ms...           k5
# 1  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k4
# 2  {'msm__dt_traj': '1 step', 'msm__lag': 25, 'ms...           k2
# 3  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k3
# 4  {'msm__dt_traj': '1 step', 'msm__connectivity'...           k4
#
#                                          test_scores  \
# 0  [3.0867290945208, 3.0808565586817154, 3.089550...
# 1  [3.067095056978774, 3.0675485197144945, 3.0711...
# 2  [1.9303607145786001, 1.942842868108373, 1.9418...
# 3  [2.618083697646979, 2.6105326052190314, 2.6098...
# 4  [3.078569698363513, 3.0932897326275817, 3.0727...
#
#                                         train_scores  run  \
# 0  [3.1047279423548604, 3.0844412189758543, 3.100...    1
# 1  [3.0831352339509692, 3.081269430199865, 3.0796...    1
# 2  [1.941609154629563, 1.9416226554503795, 1.9426...    1
# 3  [2.6118889510793286, 2.6185907907793076, 2.613...    1
# 4  [3.077536190393716, 3.0654088929117433, 3.0753...    1
#
#                       started  step  k    m  MCV_train  MCV_test
# 0  2018-01-13 17:08:53.297460     0  5  733   3.098339  3.087604
# 1  2018-01-13 17:08:53.479398     0  4  264   3.082066  3.070904
# 2  2018-01-13 17:08:54.178822     0  2  140   1.942413  1.933060
# 3  2018-01-13 17:08:54.294327     0  3  157   2.615377  2.612803
# 4  2018-01-13 17:08:54.648505     1  4  156   3.076566  3.077725

# %%
with sns.plotting_context('talk', font_scale=1):
    g = sns.FacetGrid(data=df, col='k', hue='run', sharey=True)
    g.map(plt.plot, 'step', 'MCV_test')

# %%
with sns.plotting_context('talk', font_scale=1):
    g = sns.FacetGrid(data=df, col='k', hue='run', sharey='col')
    g.map(plt.plot, 'step', 'm')

# %%
df.groupby(['project_name', 'run']).aggregate(np.max)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in f(self)
#      98         try:
# ---> 99             return self._cython_agg_general(alias, numeric_only=numeric_only)
#     100         except AssertionError as e:
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in _cython_agg_general(self, how, numeric_only)
#    3047         new_items, new_blocks = self._cython_agg_blocks(
# -> 3048             how, numeric_only=numeric_only)
#    3049         return self._wrap_agged_blocks(new_items, new_blocks)
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in _cython_agg_blocks(self, how, numeric_only)
#    3084             result, _ = self.grouper.aggregate(
# -> 3085                 block.values, how, axis=agg_axis)
#    3086
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in aggregate(self, values, how, axis)
#    1821     def aggregate(self, values, how, axis=0):
# -> 1822         return self._cython_operation('aggregate', values, how, axis)
#    1823
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in _cython_operation(self, kind, values, how, axis)
#    1757             func, dtype_str = self._get_cython_function(
# -> 1758                 kind, how, values, is_numeric)
#    1759         except NotImplementedError:
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in _get_cython_function(self, kind, how, values, is_numeric)
#    1719                                       "dtype: [how->%s,dtype->%s]" %
# -> 1720                                       (how, dtype_str))
#    1721         return func, dtype_str
#
# NotImplementedError: function is not implemented for thisdtype: [how->max,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in agg_series(self, obj, func)
#    1862         try:
# -> 1863             return self._aggregate_series_fast(obj, func)
#    1864         except Exception:
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in _aggregate_series_fast(self, obj, func)
#    1867     def _aggregate_series_fast(self, obj, func):
# -> 1868         func = self._is_builtin_func(func)
#    1869
#
# AttributeError: 'BaseGrouper' object has no attribute '_is_builtin_func'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-a46b6ddd4fc6> in <module>()
# ----> 1 df.groupby(['project_name', 'run']).aggregate(np.max)
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3595     @Appender(SelectionMixin._agg_doc)
#    3596     def aggregate(self, arg, *args, **kwargs):
# -> 3597         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    3598
#    3599     agg = aggregate
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3112
#    3113         _level = kwargs.pop('_level', None)
# -> 3114         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    3115         if how is None:
#    3116             return result
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     568         cy_func = self._is_cython_func(arg)
#     569         if cy_func and not args and not kwargs:
# --> 570             return getattr(self, cy_func)(), None
#     571
#     572         # caller can react
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in f(self)
#     101             raise SpecificationError(str(e))
#     102         except Exception:
# --> 103             result = self.aggregate(lambda x: npfunc(x, axis=self.axis))
#     104             if _convert:
#     105                 result = result._convert(datetime=True)
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3595     @Appender(SelectionMixin._agg_doc)
#    3596     def aggregate(self, arg, *args, **kwargs):
# -> 3597         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    3598
#    3599     agg = aggregate
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3120             # grouper specific aggregations
#    3121             if self.grouper.nkeys > 1:
# -> 3122                 return self._python_agg_general(arg, *args, **kwargs)
#    3123             else:
#    3124
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     775         for name, obj in self._iterate_slices():
#     776             try:
# --> 777                 result, counts = self.grouper.agg_series(obj, f)
#     778                 output[name] = self._try_cast(result, obj)
#     779             except TypeError:
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in agg_series(self, obj, func)
#    1863             return self._aggregate_series_fast(obj, func)
#    1864         except Exception:
# -> 1865             return self._aggregate_series_pure_python(obj, func)
#    1866
#    1867     def _aggregate_series_fast(self, obj, func):
#
# /Users/robert_arbon/anaconda/envs/ml4dyn/lib/python3.5/site-packages/pandas/core/groupby.py in _aggregate_series_pure_python(self, obj, func)
#    1897                 if (isinstance(res, (Series, Index, np.ndarray)) or
#    1898                         isinstance(res, list)):
# -> 1899                     raise ValueError('Function does not reduce')
#    1900                 result = np.empty(ngroups, dtype='O')
#    1901
#
# ValueError: Function does not reduce
